# %%
import pandas as pd

results_file_path = 'results/03.tsv'

# %%
df_results = pd.read_csv(results_file_path, sep='\t', header=0)
column_names = {'F1-s_full_seq':'F1-score', 'Prec_full_seq':'Precision', 'Rec_full_seq':'Recall'}
df_results.rename(columns=column_names, inplace=True)
df_results[['tool', 'model', 'prob', 'split', 'input_file', 'Precision', 'Recall', 'F1-score']]
# Out:
#        tool      model  prob  split                            input_file  \
# 0  cirCodAn  VERT_circ   0.5      0  test_TransCirc_RP_PP_evidence_hsa.fa
# 1  cirCodAn  VERT_circ   0.5      1  test_TransCirc_RP_PP_evidence_hsa.fa
# 2  cirCodAn  VERT_circ   0.5      2  test_TransCirc_RP_PP_evidence_hsa.fa
# 3  cirCodAn  VERT_circ   0.5      3  test_TransCirc_RP_PP_evidence_hsa.fa
# 4  cirCodAn  VERT_circ   0.5      4  test_TransCirc_RP_PP_evidence_hsa.fa
#
#    Precision  Recall  F1-score
# 0      97.56   83.36     89.90
# 1      97.30   79.82     87.70
# 2      97.79   80.42     88.26
# 3      97.47   80.23     88.02
# 4      96.55   80.84     88.00
