# %%
import sys
sys.path.append('../')

from lib import libdata
import numpy as np
import pandas as pd

# %%
# Input files
ribocirc_metadata_file_cd = 'riboCirc/Mouse_condition_dependent_meta.txt'
ribocirc_metadata_file_ci = 'riboCirc/Mouse_condition_independent_meta.txt'
ribocirc_circrnas_file = 'riboCirc/Mouse_circ_Sequences.fasta'
ribocirc_orfs_fasta_file = 'riboCirc/Mouse_cORF_Sequences_NA.fasta'

# Output files
circrnas_file = libdata.CIRCODAN_PATH + 'datasets/05_riboCirc_mmu.fa'
gtf_file = libdata.CIRCODAN_PATH + 'datasets/05_riboCirc_mmu.gtf'

# %%
df_ribocirc_metadata_cd = pd.read_csv(ribocirc_metadata_file_cd, sep='\t')
df_ribocirc_metadata_ci = pd.read_csv(ribocirc_metadata_file_ci, sep='\t')
df_ribocirc_metadata = pd.concat([df_ribocirc_metadata_cd, df_ribocirc_metadata_ci], ignore_index=True)
df_ribocirc_metadata
# Out:
#                  Condition Species           riboCIRC_ID Genome_assembly  \
# 0      Condition-dependent   Mouse     mmu_circRims1_001            mm10
# 1      Condition-dependent   Mouse     mmu_circPrim2_001            mm10
# 2      Condition-dependent   Mouse      mmu_circUxs1_001            mm10
# 3      Condition-dependent   Mouse    mmu_circNdufs1_001            mm10
# 4      Condition-dependent   Mouse      mmu_circPid1_001            mm10
# ..                     ...     ...                   ...             ...
# 899  Condition-independent   Mouse  mmu_circTmsb15b1_001            mm10
# 900  Condition-independent   Mouse     mmu_circAcsl4_001            mm10
# 901  Condition-independent   Mouse   mmu_circRps6ka3_001            mm10
# 902  Condition-independent   Mouse     mmu_circPdha1_001            mm10
# 903  Condition-independent   Mouse     mmu_circErdr1_001            mm10
#
#                    Genome_pos Strand  Spliced_length    Transcript    Symbol  \
# 0      chr1:22346292-22379540      -             516     NM_183018     Rims1
# 1      chr1:33628394-33630433      -             234     NM_008922     Prim2
# 2      chr1:43797244-43807377      -             182  NM_001368288      Uxs1
# 3      chr1:63148395-63148571      -             176  NM_001160039    Ndufs1
# 4      chr1:84159231-84159378      -             147  NM_001003948      Pid1
# ..                        ...    ...             ...           ...       ...
# 899  chrX:136975397-136975502      -             105  NM_001081983  Tmsb15b1
# 900  chrX:142338883-142351615      -            1324  NM_001033600     Acsl4
# 901  chrX:159337917-159352433      +             857  NM_001346675   Rps6ka3
# 902  chrX:160132068-160133232      -             234     NM_008810     Pdha1
# 903    chrY:90793295-90793417      +             122     NM_133362     Erdr1
#
#                 Ensembl  Dataset_count           Evidences  \
# 0    ENSMUSG00000041670              1     3: RPF,cORF,m6A
# 1    ENSMUSG00000026134              1         2: RPF,cORF
# 2    ENSMUSG00000057363              1     3: RPF,cORF,m6A
# 3    ENSMUSG00000025968              1         2: RPF,cORF
# 4    ENSMUSG00000045658              1      3: RPF,cORF,MS
# ..                  ...            ...                 ...
# 899  ENSMUSG00000089768              1     3: RPF,cORF,m6A
# 900  ENSMUSG00000031278              1     3: RPF,cORF,m6A
# 901  ENSMUSG00000031309              1     3: RPF,cORF,m6A
# 902  ENSMUSG00000031299              1  4: RPF,cORF,MS,m6A
# 903  ENSMUSG00000095562              4     3: RPF,cORF,m6A
#
#                    Algorithm                       Other_ids
# 0              CIRCexplorer2                             NaN
# 1    CIRI2,CIRCexplorer2,DCC                             NaN
# 2          CIRCexplorer2,DCC                             NaN
# 3              CIRCexplorer2                             NaN
# 4        CIRI2,CIRCexplorer2                             NaN
# ..                       ...                             ...
# 899                      NaN  CIRCpedia:MMU_CIRCpedia_212151
# 900                      NaN        circAtlas:mmu-Acsl4_0004
# 901                      NaN      circAtlas:mmu-Rps6ka3_0040
# 902                      NaN  CIRCpedia:MMU_CIRCpedia_212249
# 903                      NaN   CIRCpedia:MMU_CIRCpedia_33849
#
# [904 rows x 14 columns]

# %%
df_ribocirc_metadata = df_ribocirc_metadata.drop_duplicates(subset='riboCIRC_ID')
df_ribocirc_metadata.shape
# Out:
# (763, 14)

# %%
# Creating FASTA file with selected circRNAs
circ_ids = np.array(df_ribocirc_metadata['riboCIRC_ID'])
libdata.create_fasta_file_riboCirc(circ_ids, ribocirc_circrnas_file, circrnas_file)
libdata.count_sequences_in_file(circrnas_file)
# Out:
# 763

# %%
# Creating GTF file
libdata.create_gtf_file_riboCirc(circrnas_file, ribocirc_orfs_fasta_file, gtf_file)

df_gtf = pd.read_csv(gtf_file, sep='\t', header=None)
df_gtf.columns = libdata.get_gtf_columns()
df_gtf
# Out:
#                   seqname         source feature  start  end score strand  \
# 0       mmu_circRims1_001  riboCirc v1.0    cORF     33   32     .      +
# 1       mmu_circPrim2_001  riboCirc v1.0    cORF     40   39     .      +
# 2        mmu_circUxs1_001  riboCirc v1.0    cORF     24   27     .      +
# 3      mmu_circNdufs1_001  riboCirc v1.0    cORF     27  117     .      +
# 4        mmu_circPid1_001  riboCirc v1.0    cORF     13   12     .      +
# ...                   ...            ...     ...    ...  ...   ...    ...
# 1056    mmu_circAcsl4_001  riboCirc v1.0    cORF     10   32     .      +
# 1057  mmu_circRps6ka3_001  riboCirc v1.0    cORF     93  171     .      +
# 1058    mmu_circPdha1_001  riboCirc v1.0    cORF    142  141     .      +
# 1059    mmu_circPdha1_001  riboCirc v1.0    cORF    227   82     .      +
# 1060    mmu_circErdr1_001  riboCirc v1.0    cORF     79   58     .      +
#
#       frame                         attribute
# 0         2  translation_cycles=2;length=1032
# 1         0   translation_cycles=2;length=468
# 2         2   translation_cycles=1;length=186
# 3         2   translation_cycles=1;length=267
# 4         0   translation_cycles=2;length=294
# ...     ...                               ...
# 1056      0  translation_cycles=1;length=1347
# 1057      2   translation_cycles=1;length=936
# 1058      0   translation_cycles=2;length=468
# 1059      1    translation_cycles=1;length=90
# 1060      0   translation_cycles=1;length=102
#
# [1061 rows x 9 columns]
