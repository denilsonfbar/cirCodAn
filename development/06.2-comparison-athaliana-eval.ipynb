# %%
import pandas as pd

results_file_path = 'results/06.tsv'

# %%
df_results = pd.read_csv(results_file_path, sep='\t', header=0)
column_names = {'Prec_start_seq':'Precision_start_seq', 'Rec_start_seq':'Recall_start_seq', 'F1-s_start_seq':'F1-score_start_seq', 'Prec_start_cds':'Precision_start_cds', 'Rec_start_cds':'Recall_start_cds','F1-s_start_cds':'F1-score_start_cds'}
df_results.rename(columns=column_names, inplace=True)

df_results = df_results[df_results['model'] != 'PLANTS_partial']
df_results[['input_file', 'tool', 'model', 'Precision_start_seq', 'Recall_start_seq', 'F1-score_start_seq', 'Precision_start_cds', 'Recall_start_cds', 'F1-score_start_cds']]
# Out:
#            input_file          tool        model  Precision_start_seq  \
# 0  07_MStoCIRC_ath.fa      cirCodAn  PLANTS_circ                81.37
# 1  07_MStoCIRC_ath.fa      cirCodAn    VERT_circ                82.63
# 2  07_MStoCIRC_ath.fa         CodAn  PLANTS_full                70.42
# 4  07_MStoCIRC_ath.fa     ORFfinder          NaN                39.97
# 5  07_MStoCIRC_ath.fa  FragGeneScan          NaN                 2.64
# 6  07_MStoCIRC_ath.fa          CPAT          NaN                81.06
# 7  07_MStoCIRC_ath.fa          CPC2          NaN                87.50
#
#    Recall_start_seq  F1-score_start_seq  Precision_start_cds  \
# 0             92.05               86.38                81.37
# 1             82.47               82.55                82.63
# 2             49.60               58.21                70.42
# 4             93.68               56.03                15.64
# 5             88.89                5.12                 2.62
# 6             88.12               84.44                81.06
# 7              4.63                8.79                87.50
#
#    Recall_start_cds  F1-score_start_cds
# 0             74.68               77.88
# 1             69.03               75.22
# 2             40.32               51.28
# 4             38.23               22.20
# 5              2.58                2.60
# 6             71.77               76.13
# 7              4.52                8.59
