# %%
import pandas as pd

results_file_path = 'results/09.tsv'

# %%
df_results = pd.read_csv(results_file_path, sep='\t', header=0)
column_names = {'Prec_full_seq':'Precision_full_seq', 'Rec_full_seq':'Recall_full_seq', 'F1-s_full_seq':'F1-score_full_seq', 'Prec_full_cds':'Precision_full_cds', 'Rec_full_cds':'Recall_full_cds','F1-s_full_cds':'F1-score_full_cds'}
df_results.rename(columns=column_names, inplace=True)

pd.set_option('display.max_rows', None)

# %%
df_by_dataset = df_results[df_results['input_file'] == '02_TransCirc_MS_evidence_hsa.fa']
df_by_dataset[[ 'n_reps', 'input_file', 'tool', 'model', 'Precision_full_seq', 'Recall_full_seq', 'F1-score_full_seq', 'Precision_full_cds', 'Recall_full_cds', 'F1-score_full_cds']]
# Out:
#     n_reps                       input_file          tool         model  \
# 0        1  02_TransCirc_MS_evidence_hsa.fa      cirCodAn     VERT_circ
# 1        1  02_TransCirc_MS_evidence_hsa.fa         CodAn     VERT_full
# 2        1  02_TransCirc_MS_evidence_hsa.fa         CodAn  VERT_partial
# 3        1  02_TransCirc_MS_evidence_hsa.fa     ORFfinder           NaN
# 4        1  02_TransCirc_MS_evidence_hsa.fa  FragGeneScan           NaN
# 5        1  02_TransCirc_MS_evidence_hsa.fa          CPAT           NaN
# 30       2  02_TransCirc_MS_evidence_hsa.fa      cirCodAn     VERT_circ
# 31       2  02_TransCirc_MS_evidence_hsa.fa         CodAn     VERT_full
# 32       2  02_TransCirc_MS_evidence_hsa.fa         CodAn  VERT_partial
# 33       2  02_TransCirc_MS_evidence_hsa.fa     ORFfinder           NaN
# 34       2  02_TransCirc_MS_evidence_hsa.fa  FragGeneScan           NaN
# 35       2  02_TransCirc_MS_evidence_hsa.fa          CPAT           NaN
# ...

# %%
df_by_dataset = df_results[df_results['input_file'] == '04_riboCirc_hsa.fa']
df_by_dataset[[ 'n_reps', 'input_file', 'tool', 'model', 'Precision_full_seq', 'Recall_full_seq', 'F1-score_full_seq', 'Precision_full_cds', 'Recall_full_cds', 'F1-score_full_cds']]
# Out:
#     n_reps          input_file          tool         model  \
# 6        1  04_riboCirc_hsa.fa      cirCodAn     VERT_circ
# 7        1  04_riboCirc_hsa.fa         CodAn     VERT_full
# 8        1  04_riboCirc_hsa.fa         CodAn  VERT_partial
# 9        1  04_riboCirc_hsa.fa     ORFfinder           NaN
# 10       1  04_riboCirc_hsa.fa  FragGeneScan           NaN
# 11       1  04_riboCirc_hsa.fa          CPAT           NaN
# 36       2  04_riboCirc_hsa.fa      cirCodAn     VERT_circ
# 37       2  04_riboCirc_hsa.fa         CodAn     VERT_full
# 38       2  04_riboCirc_hsa.fa         CodAn  VERT_partial
# 39       2  04_riboCirc_hsa.fa     ORFfinder           NaN
# 40       2  04_riboCirc_hsa.fa  FragGeneScan           NaN
# 41       2  04_riboCirc_hsa.fa          CPAT           NaN
# 66       3  04_riboCirc_hsa.fa      cirCodAn     VERT_circ
# 67       3  04_riboCirc_hsa.fa         CodAn     VERT_full
# 68       3  04_riboCirc_hsa.fa         CodAn  VERT_partial
# ...

# %%
df_by_dataset = df_results[df_results['input_file'] == '05_riboCirc_mmu.fa']
df_by_dataset[[ 'n_reps', 'input_file', 'tool', 'model', 'Precision_full_seq', 'Recall_full_seq', 'F1-score_full_seq', 'Precision_full_cds', 'Recall_full_cds', 'F1-score_full_cds']]
# Out:
#     n_reps          input_file          tool         model  \
# 12       1  05_riboCirc_mmu.fa      cirCodAn     VERT_circ
# 13       1  05_riboCirc_mmu.fa         CodAn     VERT_full
# 14       1  05_riboCirc_mmu.fa         CodAn  VERT_partial
# 15       1  05_riboCirc_mmu.fa     ORFfinder           NaN
# 16       1  05_riboCirc_mmu.fa  FragGeneScan           NaN
# 17       1  05_riboCirc_mmu.fa          CPAT         mouse
# 42       2  05_riboCirc_mmu.fa      cirCodAn     VERT_circ
# 43       2  05_riboCirc_mmu.fa         CodAn     VERT_full
# 44       2  05_riboCirc_mmu.fa         CodAn  VERT_partial
# 45       2  05_riboCirc_mmu.fa     ORFfinder           NaN
# 46       2  05_riboCirc_mmu.fa  FragGeneScan           NaN
# 47       2  05_riboCirc_mmu.fa          CPAT         mouse
# 72       3  05_riboCirc_mmu.fa      cirCodAn     VERT_circ
# 73       3  05_riboCirc_mmu.fa         CodAn     VERT_full
# 74       3  05_riboCirc_mmu.fa         CodAn  VERT_partial
# ...

# %%
df_by_dataset = df_results[df_results['input_file'] == '06_MStoCIRC_hsa.fa']

df_by_dataset = df_by_dataset[df_by_dataset['model'] != 'VERT_partial']
df_by_dataset[[ 'n_reps', 'input_file', 'tool', 'model', 'Precision_full_seq', 'Recall_full_seq', 'F1-score_full_seq', 'Precision_full_cds', 'Recall_full_cds', 'F1-score_full_cds']]
# Out:
#     n_reps          input_file          tool      model  Precision_full_seq  \
# 18       1  06_MStoCIRC_hsa.fa      cirCodAn  VERT_circ               72.07
# 19       1  06_MStoCIRC_hsa.fa         CodAn  VERT_full               19.32
# 21       1  06_MStoCIRC_hsa.fa     ORFfinder        NaN               17.99
# 22       1  06_MStoCIRC_hsa.fa  FragGeneScan        NaN                7.95
# 23       1  06_MStoCIRC_hsa.fa          CPAT        NaN               19.23
# 48       2  06_MStoCIRC_hsa.fa      cirCodAn  VERT_circ               53.85
# 49       2  06_MStoCIRC_hsa.fa         CodAn  VERT_full               27.53
# 51       2  06_MStoCIRC_hsa.fa     ORFfinder        NaN               27.34
# 52       2  06_MStoCIRC_hsa.fa  FragGeneScan        NaN                7.95
# 53       2  06_MStoCIRC_hsa.fa          CPAT        NaN               19.31
# 78       3  06_MStoCIRC_hsa.fa      cirCodAn  VERT_circ               52.33
# ...

# %%
df_by_dataset = df_results[df_results['input_file'] == '07_MStoCIRC_ath.fa']

df_by_dataset = df_by_dataset[df_by_dataset['model'] != 'PLANTS_partial']
df_by_dataset[[ 'n_reps', 'input_file', 'tool', 'model', 'Precision_full_seq', 'Recall_full_seq', 'F1-score_full_seq', 'Precision_full_cds', 'Recall_full_cds', 'F1-score_full_cds']]
# Out:
#     n_reps          input_file          tool        model  Precision_full_seq  \
# 24       1  07_MStoCIRC_ath.fa      cirCodAn  PLANTS_circ               89.47
# 25       1  07_MStoCIRC_ath.fa         CodAn  PLANTS_full                7.82
# 27       1  07_MStoCIRC_ath.fa     ORFfinder          NaN                4.44
# 28       1  07_MStoCIRC_ath.fa  FragGeneScan          NaN                0.99
# 29       1  07_MStoCIRC_ath.fa          CPAT          NaN                4.93
# 54       2  07_MStoCIRC_ath.fa      cirCodAn  PLANTS_circ               71.38
# 55       2  07_MStoCIRC_ath.fa         CodAn  PLANTS_full               18.09
# 57       2  07_MStoCIRC_ath.fa     ORFfinder          NaN               15.13
# 58       2  07_MStoCIRC_ath.fa  FragGeneScan          NaN                0.99
# 59       2  07_MStoCIRC_ath.fa          CPAT          NaN                8.22
# 84       3  07_MStoCIRC_ath.fa      cirCodAn  PLANTS_circ               70.89
# ...
