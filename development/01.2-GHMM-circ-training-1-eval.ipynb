# %%
import pandas as pd

results_file_path = 'results/01.tsv'

# %%
df_results = pd.read_csv(results_file_path, sep='\t', header=0)
df_results[['tool', 'model', 'prob', 'split', 'input_file', 'F1-s_full_seq']]
# Out:
#         tool      model          prob  split  \
# 0   cirCodAn  VERT_circ  1.000000e-07      0
# 1   cirCodAn  VERT_circ  1.000000e-06      0
# 2   cirCodAn  VERT_circ  1.000000e-05      0
# 3   cirCodAn  VERT_circ  1.000000e-04      0
# 4   cirCodAn  VERT_circ  1.000000e-03      0
# 5   cirCodAn  VERT_circ  1.000000e-02      0
# 6   cirCodAn  VERT_circ  1.000000e-01      0
# 7   cirCodAn  VERT_circ  1.000000e-07      1
# 8   cirCodAn  VERT_circ  1.000000e-06      1
# 9   cirCodAn  VERT_circ  1.000000e-05      1
# 10  cirCodAn  VERT_circ  1.000000e-04      1
# 11  cirCodAn  VERT_circ  1.000000e-03      1
# 12  cirCodAn  VERT_circ  1.000000e-02      1
# 13  cirCodAn  VERT_circ  1.000000e-01      1
# 14  cirCodAn  VERT_circ  1.000000e-07      2
# 15  cirCodAn  VERT_circ  1.000000e-06      2
# 16  cirCodAn  VERT_circ  1.000000e-05      2
# 17  cirCodAn  VERT_circ  1.000000e-04      2
# 18  cirCodAn  VERT_circ  1.000000e-03      2
# 19  cirCodAn  VERT_circ  1.000000e-02      2
# 20  cirCodAn  VERT_circ  1.000000e-01      2
# 21  cirCodAn  VERT_circ  1.000000e-07      3
# 22  cirCodAn  VERT_circ  1.000000e-06      3
# 23  cirCodAn  VERT_circ  1.000000e-05      3
# 24  cirCodAn  VERT_circ  1.000000e-04      3
# 25  cirCodAn  VERT_circ  1.000000e-03      3
# 26  cirCodAn  VERT_circ  1.000000e-02      3
# 27  cirCodAn  VERT_circ  1.000000e-01      3
# 28  cirCodAn  VERT_circ  1.000000e-07      4
# 29  cirCodAn  VERT_circ  1.000000e-06      4
# 30  cirCodAn  VERT_circ  1.000000e-05      4
# 31  cirCodAn  VERT_circ  1.000000e-04      4
# 32  cirCodAn  VERT_circ  1.000000e-03      4
# 33  cirCodAn  VERT_circ  1.000000e-02      4
# 34  cirCodAn  VERT_circ  1.000000e-01      4
#
#                                input_file  F1-s_full_seq
# 0   train_TransCirc_RP_PP_evidence_hsa.fa          53.80
# 1   train_TransCirc_RP_PP_evidence_hsa.fa          57.51
# 2   train_TransCirc_RP_PP_evidence_hsa.fa          61.20
# 3   train_TransCirc_RP_PP_evidence_hsa.fa          65.80
# 4   train_TransCirc_RP_PP_evidence_hsa.fa          69.34
# 5   train_TransCirc_RP_PP_evidence_hsa.fa          77.21
# 6   train_TransCirc_RP_PP_evidence_hsa.fa          86.43
# 7   train_TransCirc_RP_PP_evidence_hsa.fa          54.20
# 8   train_TransCirc_RP_PP_evidence_hsa.fa          58.00
# 9   train_TransCirc_RP_PP_evidence_hsa.fa          62.45
# 10  train_TransCirc_RP_PP_evidence_hsa.fa          66.79
# 11  train_TransCirc_RP_PP_evidence_hsa.fa          70.21
# 12  train_TransCirc_RP_PP_evidence_hsa.fa          77.57
# 13  train_TransCirc_RP_PP_evidence_hsa.fa          86.76
# 14  train_TransCirc_RP_PP_evidence_hsa.fa          54.07
# 15  train_TransCirc_RP_PP_evidence_hsa.fa          57.80
# 16  train_TransCirc_RP_PP_evidence_hsa.fa          61.87
# 17  train_TransCirc_RP_PP_evidence_hsa.fa          66.65
# 18  train_TransCirc_RP_PP_evidence_hsa.fa          70.40
# 19  train_TransCirc_RP_PP_evidence_hsa.fa          77.76
# 20  train_TransCirc_RP_PP_evidence_hsa.fa          86.68
# 21  train_TransCirc_RP_PP_evidence_hsa.fa          53.42
# 22  train_TransCirc_RP_PP_evidence_hsa.fa          57.09
# 23  train_TransCirc_RP_PP_evidence_hsa.fa          60.98
# 24  train_TransCirc_RP_PP_evidence_hsa.fa          65.39
# 25  train_TransCirc_RP_PP_evidence_hsa.fa          69.29
# 26  train_TransCirc_RP_PP_evidence_hsa.fa          77.38
# 27  train_TransCirc_RP_PP_evidence_hsa.fa          86.66
# 28  train_TransCirc_RP_PP_evidence_hsa.fa          54.06
# 29  train_TransCirc_RP_PP_evidence_hsa.fa          57.56
# 30  train_TransCirc_RP_PP_evidence_hsa.fa          61.67
# 31  train_TransCirc_RP_PP_evidence_hsa.fa          66.41
# 32  train_TransCirc_RP_PP_evidence_hsa.fa          70.11
# 33  train_TransCirc_RP_PP_evidence_hsa.fa          77.80
# 34  train_TransCirc_RP_PP_evidence_hsa.fa          86.83

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_plot = df_results
column_names = {'F1-s_full_seq':'F1-score', 'Prec_full_seq':'Precision', 'Rec_full_seq':'Recall'}
df_plot.rename(columns=column_names, inplace=True)

x_axis_col = 'prob'                        
y_axis_cols = ['F1-score', 'Precision', 'Recall']

dims = (8, 4.5)
plt.subplots(figsize=dims)
plt.grid()

for col in y_axis_cols:
    sns.lineplot(data=df_plot, x=x_axis_col, y=col, legend='brief', label=col, marker='o')
    plt.xscale('log')

y_values = list(range(0, 101, 10))
plt.yticks(y_values)

plt.ylabel('Percentage of evaluation metrics')
plt.xlabel('Transition probability between NOCOD and START states')
# Out:
# Text(0.5, 0, 'Transition probability between NOCOD and START states')
